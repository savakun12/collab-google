# %% [markdown]
# # -*- coding: utf-8 -*-
# """Crawling_data_twitter (1).ipynb
#
# Automatically generated by Colab.
#
# Original file is located at
#     https://colab.research.google.com/drive/1uy9-tS2d3yy8hyJBSWdrRwd27Kz95pqp
#
# # Crawl Data Twitter > 2000 Tweets
# The crawling process was done using Tweet-Harvest. Written by Helmi Satria on March 30th 2024.
# """

# %%
#@title Twitter Auth Token

twitter_auth_token = '72c771a35d7f6302d25cb310aa7525c19a9abc58'  # Ganti dengan token autentikasi Twitter Anda

# Import required Python package
# !pip install pandas

# %%
# Install Node.js (because tweet-harvest built using Node.js)
# !sudo apt-get update
# !sudo apt-get install -y ca-certificates curl gnupg
# !sudo mkdir -p /etc/apt/keyrings
# !curl -fsSL https://deb.nodesource.com/gpgkey/nodesource-repo.gpg.key | sudo gpg --dearmor -o /etc/apt/keyrings/nodesource.gpg

# !NODE_MAJOR=20 && echo "deb [signed-by=/etc/apt/keyrings/nodesource.gpg] https://deb.nodesource.com/node_$NODE_MAJOR.x nodistro main" | sudo tee /etc/apt/sources.list.d/nodesource.list

# !sudo apt-get update
# !sudo apt-get install nodejs -y

# !node -v
# Out:
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,626 B]
# Get:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Get:3 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ Packages [55.6 kB]
# Get:4 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [858 kB]
# Get:5 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Hit:6 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:7 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Hit:8 https://ppa.launchpadcontent.net/c2d4u.team/c2d4u4.0+/ubuntu jammy InRelease
# Hit:9 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:10 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Get:11 http://security.ubuntu.com/ubuntu jammy-security/universe amd64 Packages [1,126 kB]
# Hit:12 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# ...

# %%
# Crawl Data

filename = 'motor_listrik.csv'
search_keyword = 'motor listrik lang:id until:2024-07-01 since:2020-01-01'
limit = 500

# !npx -y tweet-harvest@2.6.1 -o "{filename}" -s "{search_keyword}" --tab "LATEST" -l {limit} --token {twitter_auth_token}

import os
import pandas as pd
import re

# Verifikasi apakah file telah dibuat
if os.path.exists(filename):
    print(f"File {filename} telah berhasil dibuat.")
else:
    print(f"File {filename} tidak ditemukan setelah proses crawling.")
# Out:
# ⠙⠹⠸⠼⠴Tweet Harvest [v2.6.1]
#
# Research by Helmi Satria
# Use it for Educational Purposes only!
#
# This script uses Chromium Browser to crawl data from Twitter with your Twitter auth token.
# Please enter your Twitter auth token when prompted.
#
# Note: Keep your access token secret! Don't share it with anyone else.
# Note: This script only runs on your local device.
#
#
# Opening twitter search page...
#
#
# Found existing file ./tweets-data/motor_listrik.csv, renaming to ./tweets-data/motor_listrik.old.csv
#
# Filling in keywords: motor listrik lang:id until:2024-07-01 since:2020-01-01
#
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/motor_listrik.csv
# Total tweets saved: 17
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/motor_listrik.csv
# Total tweets saved: 30
#
#
# Your tweets saved to: /content/tweets-data/motor_listrik.csv
# Total tweets saved: 45
#
# -- Scrolling... (1)
#
# ...

# %%
# Specify the path to your CSV file
file_path = filename  # "tweets-data/" prefix not necessary if file is in the same directory

# Verify if file exists
if os.path.exists(file_path):
    # Read the CSV file into a pandas DataFrame
    df = pd.read_csv(file_path, delimiter=",")

    # Display the DataFrame
    display(df)

    # Cek jumlah data yang didapatkan
    num_tweets = len(df)
    print(f"Jumlah tweet dalam dataframe adalah {num_tweets}.")

    # Pembersihan Data

    # Menghapus baris yang tidak diperlukan
    df = df.dropna(subset=['created_at', 'user_screen_name', 'text'])

    # Mengubah format tanggal
    df['created_at'] = pd.to_datetime(df['created_at'], errors='coerce')

    # Membersihkan nama pengguna
    df['user_screen_name'] = df['user_screen_name'].str.strip().str.lower()

    # Membersihkan isi tweet
    def bersihkan_tweet(tweet):
        tweet = re.sub(r'http\S+', '', tweet)  # Menghapus URL
        tweet = re.sub(r'@\w+', '', tweet)     # Menghapus mention
        tweet = re.sub(r'#\w+', '', tweet)     # Menghapus hashtag
        tweet = re.sub(r'[^\w\s]', '', tweet)  # Menghapus karakter khusus
        tweet = tweet.lower()                  # Mengubah ke huruf kecil
        return tweet

    df['text'] = df['text'].apply(bersihkan_tweet)

    # Mengatasi duplikasi
    df = df.drop_duplicates()

    # Mengganti nama kolom sesuai keinginan
    df = df.rename(columns={'created_at': 'tanggal', 'user_screen_name': 'nama_user', 'text': 'isi_tweet'})

    # Memilih kolom yang relevan
    df = df[['tanggal', 'nama_user', 'isi_tweet']]

    # Menyimpan data yang telah dibersihkan ke dalam file CSV
    df.to_csv('motor_listrik_bersih.csv', index=False)

    # Display cleaned DataFrame
    display(df)
    print(f"Data yang telah dibersihkan disimpan dalam 'motor_listrik_bersih.csv'.")
else:
    print(f"File {file_path} tidak ditemukan.")
# Out:
# File motor_listrik.csv tidak ditemukan.
